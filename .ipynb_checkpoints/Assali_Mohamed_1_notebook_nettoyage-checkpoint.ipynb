# %% [markdown]
# # Projet_3: Concevez une application au service de la santé publique

# %% [markdown]
# ### Chargement des librairies

# %%
from urllib import request
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import pyplot, transforms
import seaborn as sns
import numpy as np
import re
import IPython.display
sns.set()

# %% [markdown]
# Lien vers les consignes du projet sur openclassrooms : https://openclassrooms.com/fr/projects/628/assignment

# %% [markdown]
# Description du jeu de données : https://world.openfoodfacts.org/data/data-fields.txt

# %% [markdown]
# lecture des données

# %%
filepath = '/Users/admin/Desktop/formation_data_Scientist/projet_3/données/A/openfoodfacts.org.products.csv'

# %%
df = pd.read_csv(filepath,  sep = '\t', low_memory=False)

# %%
total_nan_values = df.isnull().sum().sum()
print (total_nan_values)
# Out:
# 39608589

# %%
# Afficher le nombre total et le percentage des valeurs nulles

def print_null_pct(df):
    tot_null = df.isna().sum().sum()
    print('nb of null: ', tot_null, '\npct of null: ',
        '{:.1f}'.format(tot_null*100/(df.shape[0]*df.shape[1])))

print_null_pct(df)
# Out:
# nb of null:  39608589
# pct of null:  76.2

# %% [markdown]
# ## 1 - Nettoyage du je de données

# %% [markdown]
# ### 1.1 Filtre sur les produits vendus en France

# %%
for i in df['countries'].unique():
    if 'Fr' in str(i):
        print(i)
# Out:
# France
# France, US
# France,Royaume-Uni
# UK,France
# France,Belgique,Pays-Bas,Royaume-Uni
# France,United Kingdom
# France,UK
# Royaume-Uni,France
# France,Suisse,États-Unis,Canada
# Belgique,France
# Belgique,France,Pays-Bas,Royaume-Uni
# France,United States
# France, Suisse
# France,États-Unis
# France,États-Unis,Suisse
# Frankreich,Deutschland
# France,Italie
# United Kingdom,France
# France,United Kingdom,United States
# France,Switzerland
# Australia,France,United Kingdom
# France,United Kingdom, US
# France,Belgique,Royaume-Uni,Pays-Bas
# UK,France,US
# France,Canada
# Canada,France
# Belgique,Canada,France,Suisse
# France,Saint Pierre and Miquelon
# France, en:switzerland
# France,Royaume-Uni, Suisse
# France,New Zealand
# Belgique,France,Royaume-Uni,Pays-Bas
# France,Suisse,États-Unis
# UK,France,Belgium
# Belgium,France,Netherlands,United Kingdom
# France,Australia
# Canada,France,États-Unis
# Belgique,France,Royaume-Uni
# France,Pays-Bas
# ...

# %%
df.dtypes.unique()
# Out:
# array([dtype('O'), dtype('float64')], dtype=object)

# %%
df['countries_fr'].unique()
# Out:
# array(['France', 'États-Unis', 'Royaume-Uni', 'France,États-Unis',
#        'Canada', 'Suisse', 'Espagne', 'Allemagne', 'Slovénie', 'Italie',
#        'Roumanie', 'Australie', 'Portugal', 'France,Royaume-Uni',
#        'Belgique,France,Pays-Bas,Royaume-Uni', 'Guadeloupe', nan,
#        'Royaume-Uni,États-Unis', 'Canada,États-Unis', 'Pays-Bas',
#        'Australie,France', 'Canada,France,Suisse,États-Unis',
#        'France,États-Unis,en:Etats-unis', 'Irlande', 'France,La Réunion',
#        'Taiwan', 'Australie,Suisse', 'France,Allemagne', 'Brésil',
#        'Belgique,France', 'République dominicaine',
#        'États-Unis,en:Australie', 'Arabie saoudite',
#        'Émirats arabes unis', 'Irak', 'Koweït', 'Moldavie', 'Belgique',
#        'Nouvelle-Calédonie', 'Singapour', 'Finlande',
#        'Australie,États-Unis', 'France,Suisse',
#        'Australie,Nouvelle-Zélande,Singapour,Thaïlande,États-Unis',
#        'Polynésie française', 'Panama', 'Costa Rica', 'Mexique',
# ...

# %%
def filtre_coutry_france(df):
    liste_pays = ['France', 'FR', 'en:FR', 'en:fr', 'en:France', 'Frankreich', 
              'france', 'Réunion', 'Francia', 'French Polynesia', 'Frankrijk', 
              'Nouvelle-Calédonie', 'Martinique', 'Guadeloupe', 
              'Polynésie Française', 'Mayotte']
    df = df[df['countries_fr'].isin(liste_pays)]
    return df 
df_FR = filtre_coutry_france(df)

# %%
df_FR = filtre_coutry_france(df)

# %% [markdown]
# ## 2- Nettoyages des variables

# %% [markdown]
# ### 2.1 Supression des colonnes moins renseignées

# %%
K = (df_FR.isna().sum()/len(df_FR)*100).sort_values(ascending = False)
#plt.figure(figsize=(10, 30))
fig, ax = plt.subplots(figsize = (10, 30))
ax.barh(y = K.index, width = K.values)
ax.set_title('Pourcentage des données existantes)')
ax.invert_yaxis()
ax.set_ylabel('Name')
ax.xaxis.set_ticks_position('top')
ax.set_xlabel('Pourcentage')
ax.grid(False)

# %%
def clean_nan(df) :
    ''' Suppression des colonnes ayant 
    moins de valeurs que le taux de rétention.
    Renvoie en sortie la dataframe sans les colonnes non conservées'''
    non_nan_quantity = df.isna().sum()/len(df_FR)*100

    nb_NaN = df.shape[1]
    
    df = df[non_nan_quantity[non_nan_quantity <= 70].index.tolist()]
    
    nb_NaN = nb_NaN - df.shape[1]
    
    print('Nombre de colonnes supprimées :', nb_NaN)
    
    return df

# %%
df_FR.shape
# Out:
# (94675, 162)

# %%
df_FR = clean_nan(df_FR)
# Out:
# Nombre de colonnes supprimées : 109

# %%
df_FR.shape
# Out:
# (94675, 53)

# %% [markdown]
# 2.1.1 Supression des varibles redendantes

# %%
df_FR.columns
# Out:
# Index(['code', 'url', 'creator', 'created_t', 'created_datetime',
#        'last_modified_t', 'last_modified_datetime', 'product_name',
#        'generic_name', 'quantity', 'packaging', 'packaging_tags', 'brands',
#        'brands_tags', 'categories', 'categories_tags', 'categories_fr',
#        'labels', 'labels_tags', 'labels_fr', 'purchase_places', 'stores',
#        'countries', 'countries_tags', 'countries_fr', 'ingredients_text',
#        'additives_n', 'additives', 'additives_tags', 'additives_fr',
#        'ingredients_from_palm_oil_n',
#        'ingredients_that_may_be_from_palm_oil_n', 'nutrition_grade_fr',
#        'pnns_groups_1', 'pnns_groups_2', 'states', 'states_tags', 'states_fr',
#        'main_category', 'main_category_fr', 'image_url', 'image_small_url',
#        'energy_100g', 'fat_100g', 'saturated-fat_100g', 'carbohydrates_100g',
#        'sugars_100g', 'fiber_100g', 'proteins_100g', 'salt_100g',
# ...

# %% [markdown]
# ### 2.2 Supression des variables redondantes

# %% [markdown]
# Nous constatons l'existence des variables redondantes dans le jeu de donneé. Notons par exemple  states, states_tags et states_fr, ces trois variabes sont nommées différemment mais donnent les memes informations.

# %%
df[["sodium_100g", "salt_100g"]].corr()
# Out:
#              sodium_100g  salt_100g
# sodium_100g          1.0        1.0
# salt_100g            1.0        1.0

# %%
df[['countries_tags', 'countries', 'countries_fr' ]].head(10)
# Out:
#      countries_tags countries countries_fr
# 0         en:france     en:FR       France
# 1  en:united-states        US   États-Unis
# 2  en:united-states        US   États-Unis
# 3  en:united-states        US   États-Unis
# 4  en:united-states        US   États-Unis
# 5  en:united-states        US   États-Unis
# 6  en:united-states        US   États-Unis
# 7  en:united-states        US   États-Unis
# 8  en:united-states        US   États-Unis
# 9  en:united-states        US   États-Unis

# %%
def remove_columns(dataframe) :
    columns_to_delete = ['countries', 'brands', 'additives', 'states', 'states_tags', 'nutrition-score-uk_100g', 'last_modified_t', 'created_t', 'salt_100g']
    for column in columns_to_delete:
        try:
            dataframe = dataframe.drop(column, axis = 1)
        except:
            print('........colonne non présente : ', column)
    print('\n')
    return dataframe

# %%
df_FR_clean = remove_columns(df_FR)

# %% [markdown]
# ## 3- Nettoyages des lignes

# %% [markdown]
# ### 3.1 Suppression des valeurs abérantes

# %%
ind = df_FR_clean[(df_FR_clean["proteins_100g"] > 100)
                                  | ((df_FR_clean["sugars_100g"] > 100)| (df_FR_clean["sugars_100g"] < 0))
                                  | ((df_FR_clean["fat_100g"] > 100) | (df_FR_clean["fat_100g"] < 0))
                                  | ((df_FR_clean["proteins_100g"]> 100) | (df_FR_clean["proteins_100g"]< 0))
                                  | ((df_FR_clean["fiber_100g"]> 100) | (df_FR_clean["fiber_100g"]< 0))
                                  | ((df_FR_clean["saturated-fat_100g"] > 100) | (df_FR_clean["saturated-fat_100g"] < 0))
                                  | ((df_FR_clean["carbohydrates_100g"] > 100)  | (df_FR_clean["carbohydrates_100g"] < 0))
                                  | ((df_FR_clean["sodium_100g"] > 100) | (df_FR_clean["sodium_100g"] < 0))
                                  | ((df_FR_clean["energy_100g"] > 3700) | (df_FR_clean["energy_100g"] < 0))] 
#df_FR_clean = df_FR_clean.drop(axis=0, index=ind.index)

# %%
ind
# Out:
#                  code                                                url  \
# 56561   0043647390011  http://world-fr.openfoodfacts.org/produit/0043...
# 68125   0068100083859  http://world-fr.openfoodfacts.org/produit/0068...
# 115370  0411015621416  http://world-fr.openfoodfacts.org/produit/0411...
# 155609  0838619000254  http://world-fr.openfoodfacts.org/produit/0838...
# 161426  0853807005163  http://world-fr.openfoodfacts.org/produit/0853...
# ...               ...                                                ...
# 316993  8851613003276  http://world-fr.openfoodfacts.org/produit/8851...
# 317235  8857101221801  http://world-fr.openfoodfacts.org/produit/8857...
# 317635  8935000901649  http://world-fr.openfoodfacts.org/produit/8935...
# 319695  9310804500189  http://world-fr.openfoodfacts.org/produit/9310...
# 320561  9556001171337  http://world-fr.openfoodfacts.org/produit/9556...
#
#                            creator      created_datetime  \
# ...

# %%
df_FR_clean = df_FR_clean.drop(axis=0, index=ind.index)

# %%
ind.shape
# Out:
# (262, 44)

# %% [markdown]
# 2.2.2 supression les lignes non rensignées pour les variables quantitatives

# %%
def supp_cases_nulles(dataframe):
    outliers_100g = dataframe[dataframe["energy_100g"].isna()
                            & dataframe["proteins_100g"].isna()
                            & dataframe["sugars_100g"].isna()
                            & dataframe["fat_100g"].isna()
                            & dataframe["fiber_100g"].isna() 
                            & dataframe["saturated-fat_100g"].isna()
                            & dataframe["carbohydrates_100g"].isna()
                            & dataframe["sodium_100g"].isna()] 
    dataframe= dataframe.drop(axis=0, index=outliers_100g.index)
    print('le nombre de lignes suprimés est:', outliers_100g.shape[0])
    print('le jeu de données est des outelires est le suivant:')
    display(outliers_100g)
    return dataframe

# %%
outliers_100g = df_FR_clean[df_FR_clean["energy_100g"].isna()
                            & df_FR_clean["proteins_100g"].isna()
                            & df_FR_clean["sugars_100g"].isna()
                            & df_FR_clean["fat_100g"].isna()
                            & df_FR_clean["fiber_100g"].isna() 
                            & df_FR_clean["saturated-fat_100g"].isna()
                            & df_FR_clean["carbohydrates_100g"].isna()
                            & df_FR_clean["sodium_100g"].isna()]

# %%
outliers_100g
# Out:
# Empty DataFrame
# Columns: [code, url, creator, created_datetime, last_modified_datetime, product_name, generic_name, quantity, packaging, packaging_tags, brands_tags, categories, categories_tags, categories_fr, labels, labels_tags, labels_fr, purchase_places, stores, countries_tags, countries_fr, ingredients_text, additives_n, additives_tags, additives_fr, ingredients_from_palm_oil_n, ingredients_that_may_be_from_palm_oil_n, nutrition_grade_fr, pnns_groups_1, pnns_groups_2, states_fr, main_category, main_category_fr, image_url, image_small_url, energy_100g, fat_100g, saturated-fat_100g, carbohydrates_100g, sugars_100g, fiber_100g, proteins_100g, sodium_100g, nutrition-score-fr_100g]
# Index: []
#
# [0 rows x 44 columns]

# %%
df_FR_clean = supp_cases_nulles(df_FR_clean)
# Out:
# le nombre de lignes suprimés est: 32611
# le jeu de données est des outelires est le suivant:
#                  code                                                url  \
# 0       0000000003087  http://world-fr.openfoodfacts.org/produit/0000...
# 46      0000000024600  http://world-fr.openfoodfacts.org/produit/0000...
# 48      0000000027205  http://world-fr.openfoodfacts.org/produit/0000...
# 136     0000000039259  http://world-fr.openfoodfacts.org/produit/0000...
# 182     0000005200016  http://world-fr.openfoodfacts.org/produit/0000...
# ...               ...                                                ...
# 320760       99044169  http://world-fr.openfoodfacts.org/produit/9904...
# 320761  9906410000009  http://world-fr.openfoodfacts.org/produit/9906...
# 320764           9918  http://world-fr.openfoodfacts.org/produit/9918...
# 320765  9935010000003  http://world-fr.openfoodfacts.org/produit/9935...
# 320770  9980282863788  http://world-fr.openfoodfacts.org/produit/9980...
# ...

# %%
def check_unknown(data):
    """
    Check if "unknown" value is present for some observations for each variable in the dataframe.
    
    Args:
        data(dataframe) : A dataframe to be checked
    Returns:
        Number of observations with an "unknow" value for each stream
    """
    
    unknown_dict = {}
    
    for col in data.columns:
        unknown_dict[col] = data[data[col] =="unknown"].shape[0]
    
    return pd.DataFrame.from_dict(data=unknown_dict, orient ="index", columns = ["Nombre d'observations unknown"]).sort_values(by="Nombre d'observations unknown", ascending=False)

check_unknown(df_FR_clean)
# Out:
#                                          Nombre d'observations unknown
# pnns_groups_1                                                     7454
# pnns_groups_2                                                     7454
# code                                                                 0
# url                                                                  0
# additives_fr                                                         0
# ingredients_from_palm_oil_n                                          0
# ingredients_that_may_be_from_palm_oil_n                              0
# nutrition_grade_fr                                                   0
# states_fr                                                            0
# main_category                                                        0
# main_category_fr                                                     0
# image_url                                                            0
# ...

# %% [markdown]
# ## 4- Remplacement des valeurs manquantes

# %% [markdown]
# ### 4.1 Remplacement des valeurs manquantes par la méthode Iterative Imputer

# %%
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer

# %%
df_imput_it_sklearn = df_FR_clean.copy()
df_imput_it_sklearn = df_imput_it_sklearn.select_dtypes(['int32','float64'])
def imput_iter_skealearn(df):
    imp = IterativeImputer(max_iter=10, verbose=2 , tol = 1e-8 )
    imp.fit_transform(df_imput_it_sklearn)
    data_imputed = pd.DataFrame(imp.fit_transform(df_imput_it_sklearn), columns=df_imput_it_sklearn.columns)
    print('Le nombre pourcentage de NaN dans les variables quantitatives est:', data_imputed.isna().sum())
    display(data_imputed)
    return data_imputed
data_imputed = imput_iter_skealearn(df_imput_it_sklearn)
# Out:
# [IterativeImputer] Completing matrix with shape (61802, 12)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.49
# [IterativeImputer] Change: 2490.7876577866778, scaled tolerance: 3.7e-05
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.93
# [IterativeImputer] Change: 560.2409804818215, scaled tolerance: 3.7e-05
# [IterativeImputer] Ending imputation round 3/10, elapsed time 1.40
# [IterativeImputer] Change: 80.41053176255596, scaled tolerance: 3.7e-05
# [IterativeImputer] Ending imputation round 4/10, elapsed time 1.86
# [IterativeImputer] Change: 48.044207755667216, scaled tolerance: 3.7e-05
# [IterativeImputer] Ending imputation round 5/10, elapsed time 2.28
# [IterativeImputer] Change: 43.26527686299064, scaled tolerance: 3.7e-05
# [IterativeImputer] Ending imputation round 6/10, elapsed time 2.69
# [IterativeImputer] Change: 41.357200427485765, scaled tolerance: 3.7e-05
# [IterativeImputer] Ending imputation round 7/10, elapsed time 3.07
# ...

# %%
#df_clean_median['X'] = 'UNKNOWN'

# %%
#for score in range(len(df_clean_median['nutrition-score-fr_100g'])):
   # if df_clean_median['nutrition-score-fr_100g'][score] >= - 25 and df_clean_median['nutrition-score-fr_100g'][score] <= -1 : 
           #  df_clean_median['X'][score]= df_clean_median['X'][score].replace('UNKNOWN', 'a')
   # if df_clean_median['nutrition-score-fr_100g'][score] >= 0 and df_clean_median['nutrition-score-fr_100g'][score] <= 2: 
             #df_clean_median['X'][score]= df_clean_median['X'][score].replace('UNKNOWN', 'b')
   # if df_clean_median['nutrition-score-fr_100g'][score] >= 3 and df_clean_median['nutrition-score-fr_100g'][score] <= 10: 
            # df_clean_median['X'][score]= df_clean_median['X'][score].replace('UNKNOWN', 'c')
    #if df_clean_median['nutrition-score-fr_100g'][score] >= 11 and df_clean_median['nutrition-score-fr_100g'][score] <= 18: 
            # df_clean_median['X'][score]= df_clean_median['X'][score].replace('UNKNOWN', 'd')
    #if df_clean_median['nutrition-score-fr_100g'][score] >= 19 and df_clean_median['nutrition-score-fr_100g'][score] <= 40: 
           #  df_clean_median['X'][score]= df_clean_median['X'][score].replace('UNKNOWN', 'e')

# %% [markdown]
# ### 4.2 Remplacement des valeurs manquantes par la médiane en fonction du nutriscore grade

# %%
def imput_median(df):
    for cols in df.columns:
        if df[cols].dtypes == "float64":
            df[cols].fillna(df.groupby('nutrition_grade_fr')[cols].transform('median'), inplace = True)
    return df

# %%
df_clean_median = df_FR_clean.copy()
df_clean_median = df_clean_median[df_clean_median['nutrition_grade_fr'].isna() == False]
df_clean_median.reset_index(inplace=True, drop=True)

# %%
imput_median(df_clean_median)
# Out:
#                 code                                                url  \
# 0      0000010187319  http://world-fr.openfoodfacts.org/produit/0000...
# 1      0000010207260  http://world-fr.openfoodfacts.org/produit/0000...
# 2      0000040608754  http://world-fr.openfoodfacts.org/produit/0000...
# 3      0000069161025  http://world-fr.openfoodfacts.org/produit/0000...
# 4      0000087177756  http://world-fr.openfoodfacts.org/produit/0000...
# ...              ...                                                ...
# 58205  9782211109758  http://world-fr.openfoodfacts.org/produit/9782...
# 58206  9782401029101  http://world-fr.openfoodfacts.org/produit/9782...
# 58207  9847548283004  http://world-fr.openfoodfacts.org/produit/9847...
# 58208  9900000000233  http://world-fr.openfoodfacts.org/produit/9900...
# 58209       99111250  http://world-fr.openfoodfacts.org/produit/9911...
#
#          creator      created_datetime last_modified_datetime  \
# ...

# %%
df_clean_median.isna().sum()
# Out:
# code                                           0
# url                                            0
# creator                                        0
# created_datetime                               0
# last_modified_datetime                         0
# product_name                                 294
# generic_name                               30509
# quantity                                   15388
# packaging                                  18728
# packaging_tags                             18728
# brands_tags                                  289
# categories                                 16327
# categories_tags                            16327
# categories_fr                              16327
# labels                                     32193
# labels_tags                                32158
# labels_fr                                  32158
# purchase_places                            27338
# stores                                     30462
# ...

# %%
taille_jeux = pd.DataFrame({'Nom' : ['données initiales', 'données nettoyées'],
                           
                            'Dimensions' : [df.shape, 
                                           df_clean_median.shape],
                           
                            'Proportion de NaN (en %)' :
                            [df.isna().sum().sum()/df.shape[0]/df.shape[1]*100,
                             df_clean_median.isna().sum().sum()/
                             df_clean_median.shape[0] / 
                             df_clean_median.shape[1]*100]
    })

# %%
taille_jeux
# Out:
#                  Nom     Dimensions  Proportion de NaN (en %)
# 0  données initiales  (320772, 162)                 76.221573
# 1  données nettoyées    (58210, 44)                 19.065140

# %%
df_clean_median.to_csv('/Users/admin/Desktop/formation_data_Scientist/projet_3/données/A/cleaned_data1.csv', index=False)
