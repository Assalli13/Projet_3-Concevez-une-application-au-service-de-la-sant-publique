# %%
from urllib import request
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import pyplot, transforms
import seaborn as sns
import numpy as np
import re
from matplotlib.patches import Polygon
import IPython.display
sns.set()

# %%
filepath = '/Users/admin/Desktop/formation_data_Scientist/projet_3/données/A/cleaned_data1.csv'

# %%
df = pd.read_csv(filepath)

# %% [markdown]
# ## 1- Analyse Univariée

# %%
cols = df.columns.drop('additives_n','ingredients_that_may_be_from_palm_oil_n')

# %%
df['nutrition-score-fr_100g'] = df['nutrition-score-fr_100g'].astype('float64', errors = 'raise')

# %%
for col in df.select_dtypes(include = ['float64']).columns.tolist():
        fig = plt.figure(figsize = (18, 8))
        gs = fig.add_gridspec(1,2)
        ax = fig.add_subplot(gs[0,0])
        ax1 = fig.add_subplot(gs[0,1])
        #ax1 = Histogramme
        #sns.kdeplot(df[col], ax = ax)
        sns.histplot(df[col], ax = ax,  bins="sturges",  kde = True)
        ax.lines[0].set_color('green')
        ax.set_xlabel(col)
        ax.set_ylabel("Nombre d'observations")
        ax.set_title('Histogramme de la variable'+ col )
        #ax1: Boite à Maustache
        sns.boxplot(df[col])
        ax1.set_xlabel(col)
        ax1.set_title('Distribution de :' + col )
        plt.show()
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ...

# %%
plt.figure(figsize=(8,8))

plt.title('Répartition des Nutriscores', size=20)
wedges, texts, autotexts = plt.pie(df.nutrition_grade_fr.value_counts().values, 
        labels = df.nutrition_grade_fr.value_counts().index.str.upper(),
       autopct='%1.1f%%', textprops={'fontsize': 16})

ax = plt.gca()

ax.legend(wedges, df.nutrition_grade_fr.value_counts().index.str.upper(),
          title="Note",
          loc="center left",
          fontsize=14,
          bbox_to_anchor=(1, 0, 0.5, 1))

# %% [markdown]
# Si toutes les modalités ne sont pas également représentées elles le sont tout de même significativement. Il n'y a pas de déséquilibre fort notable. Notons tout de même une modalité "d" plus représentée (29%) et un modalités "b" moins représentée (13%).

# %% [markdown]
# ## 2- Analyse bivariée

# %% [markdown]
# ### 2.1 Analyse de régression entre variables quantitatives

# %%
plot_cols =  ["additives_n", "energy_100g", "proteins_100g", "sugars_100g", "fat_100g", "saturated-fat_100g", "carbohydrates_100g", "sodium_100g", 'nutrition_grade_fr']
quant_data = df.loc[:,plot_cols]
sns.pairplot(data=quant_data, kind="reg", plot_kws={'line_kws':{'color':'red'}})
plt.show()

# %% [markdown]
# Les rapréaentation pairplot réalisées, à l'aide de seaborn, pour la variables quantitatives ont été choisie de trouver des corrélations entre ces différentes variables.
# En effet, plus la déviation du nuage de points par rapport à la droite d'ajustement est moins importante plus les deux varibles sont des doublons.
#
# A partir de ces résultats nous pouvons constaté qu'aucune nuage de points n'a une forme similaire a une droite. Aucune variable quantitaive n'est considérée comme doublons.

# %% [markdown]
# ### 2.2 Quantité de chaque macronutriement en fonction du Nutri-Score

# %%
macro_nutriments_labels = []
for col in df :
    if "_100g" in col :
        macro_nutriments_labels.append(col)
data_for_plot = df[macro_nutriments_labels + ["nutrition_grade_fr"]].dropna(subset=["nutrition_grade_fr"])
data_for_plot = data_for_plot.explode(macro_nutriments_labels)
data_for_plot[macro_nutriments_labels]= data_for_plot[macro_nutriments_labels].astype('float')
order = sorted(df["nutrition_grade_fr"].dropna().unique())
labels = ['A', 'B', 'C', 'D', 'E']
y_pos = np.arange(len(labels))
for macro_nutri in macro_nutriments_labels :
    sns.boxplot(data=data_for_plot, x ='nutrition_grade_fr', y=macro_nutri, order=order, showfliers=False, palette={'a':"#499A53", 'b':"#74D834", 'c':"#FBF605", 'd':"#F49402", 'e':"#FF0000"})
    plt.xticks(y_pos, labels)
    plt.suptitle('scatter plot of {}'.format(macro_nutri),
             fontweight='bold', fontsize=16)
    plt.show()

# %% [markdown]
# Plus il y a de sucre, de graisses et de sel dans un produit et plus son Nutri-Score est mauvais
# Plus un aliment est riche en fibre, plus sa probabilité d'être de mauvaise qualité nutritionnelle est faible
# On retrouve donc bien sur ces graphiques les principes de la méthode de calcul du Nutri-Score

# %% [markdown]
# ### 2.3 Matrice de corrélation

# %%
corr_matrix = df.corr()
mask = np.triu(corr_matrix)
plt.figure(figsize=(10,8))
sns.heatmap(corr_matrix, cmap="coolwarm", mask=mask, linewidths=.5, annot=True, cbar=True, square=True)
plt.title("Matrice de corrélation des variables quantitatives")
#plt.savefig("Présentation/Images/matrice_corr.png")
plt.show()

# %% [markdown]
# Nous constatons des corrélations linéaires positives fortes entre les variables fat_100g et energy_100g (70%) ainsi que entre fat_100g et saturated-fat_100g (69%). Dans une moindre mesure nous observons une corrélation positive du nutrition-scrore-fr_100g avec plusieurs variables de nutriements:
#
# saturated_fat_100g (61%)
# energy_100g (63%)
# fat_100g (64%)
# sugars_100g (45%)
# Afin de valider une éventuelle normalité nous procédons à un test statistique d'indépendance de Pearson sur ces couples de variables.

# %% [markdown]
# ## 2- Analyse Multivariée

# %% [markdown]
# ### 3.1 Réduction de dimensions par Analyse en composantes principales

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
import math

# %%
df.select_dtypes(['float64']).shape
# Out:
# (58210, 12)

# %%
data_pca = df.select_dtypes(['float64']).dropna()

# %%
colonnes_pca = data_pca.columns

# %%
scaler = StandardScaler()
data_pca = scaler.fit_transform(data_pca)

# %%
pca = PCA(n_components = data_pca.shape[1])

# %%
pca.fit(data_pca)
# Out:
# PCA(n_components=12)

# %%
pca.explained_variance_ratio_
# Out:
# array([0.28210068, 0.15263488, 0.1143817 , 0.09816664, 0.08241858,
#        0.06610902, 0.061408  , 0.04908182, 0.0381189 , 0.03039346,
#        0.01695796, 0.00822835])

# %%
plt.figure(figsize=(12,5))
plt.title('Somme cumulée de variance des composantes de l\'ACP')
plt.xlabel('Nombre de composantes de l\'ACP')
plt.ylabel('Variance cumulée')
plt.plot(np.linspace(2, 12,12),
         np.cumsum(pca.explained_variance_ratio_))

# %%
pca.components_
# Out:
# array([[ 0.14873634,  0.24835581,  0.14324087,  0.47322617,  0.4099651 ,
#          0.38823774,  0.25049318,  0.26116981,  0.01509226,  0.06379935,
#          0.01863882,  0.46619091],
#        [ 0.33568442,  0.21385159,  0.27384121, -0.10394924, -0.33764471,
#         -0.31885403,  0.41954212,  0.42347697, -0.05588487, -0.39920834,
#         -0.14443592, -0.03763879],
#        [-0.5039591 , -0.12660634, -0.45766036,  0.207251  , -0.08239058,
#         -0.06784391,  0.37687759,  0.30846798,  0.42527432,  0.00860383,
#         -0.19765172, -0.09492831],
#        [ 0.23415373,  0.1354383 ,  0.31944458,  0.09335672, -0.14247734,
#         -0.14239969,  0.14934705, -0.19346931,  0.62609143,  0.50081302,
#          0.21375487, -0.16510757],
#        [-0.07970821,  0.03424479, -0.24138557, -0.0740402 , -0.11298039,
#         -0.12547673,  0.12130602,  0.17353031, -0.12701855, -0.01149479,
#          0.90056479,  0.16764624],
# ...

# %%
norms = np.linalg.norm(pca.components_[0:6], axis=0)
normes = pd.DataFrame(norms).T
normes.columns = colonnes_pca
normes = normes.T.reset_index()
normes.columns = ['feature', 'norme']
normes.sort_values(by='norme', inplace=True, ascending=False)
plt.figure(figsize=(6,6))
plt.title('Importance relative des features dans \n les 11 premières composantes de l\'ACP')
sns.barplot(y = normes['feature'],
            x = normes['norme'])

# %% [markdown]
# On voit qu'à partir de 11 features on a une variance cumulée de plus de 95 %. On pourrait donc réduire notre jeu de données à 11 dimensions si on souhaitait gagner en temps de calcul / volume de données.

# %%
from matplotlib.patches import Circle
sns.set_context("paper", font_scale=1.5) 
plt.figure(figsize=(15,15))
chaine = "Plan factoriel pour les 2 premières composantes de l'ACP"
plt.title(chaine)
plt.xlabel('F1')
plt.ylabel('F2')
ax = plt.gca()
ax.add_patch(Circle([0,0], radius=1, color='black', fill=False, linestyle='-', clip_on=False))
ax.set_xlim(-1,1)
ax.set_ylim(-1,1)
x_pca = pca.components_[0,:]
y_pca = pca.components_[1,:]

sns.scatterplot(x = x_pca,y = y_pca,alpha = 0.7)
plt.plot([-1,1],[0,0], color='grey', alpha=0.8)
plt.plot([0,0],[-1,1], color='grey', alpha=0.8)

i = 0
for x,y,colonne in zip(x_pca,y_pca, colonnes_pca):

    plt.annotate(colonne, (x,y), textcoords="offset points", xytext=(0,5+np.random.randint(-10,10)),
                 ha='center') 
    ax.arrow(0, 0, x, y, head_width=0, head_length=0, fc='grey', ec='grey',alpha=0.2)


sns.set_context("paper", font_scale=1)

# %% [markdown]
# ## 4- Prédiction des valeurs manquantes du Nutriscore par régression linéaire

# %%
#from scipy import stats
#numeric_columns = df.select_dtypes(include = ['float64']).columns
#numeric_columns = numeric_columns[1:]
#for column in numeric_columns:
  #  print('________\n{}'.format(column))
   # k2, p = stats.normaltest(df[column], axis=0, nan_policy = 'omit')
    #alpha = 5e-2
    #print("p = {:g}".format(p))
    #if p < alpha:  # null hypothese: x a une distribution normale
       # print("Premiere hypothèse  : les variables sont indépendantes est rejetée : {} n'est pas de distribution normale".format(column))
    #el#se:
        #print("Premiere hypothèse  : les variables sont indépendantes ne peut être rejetée :{}, on considère l'hypothèse de normalité".format(column))

# %%
data_reg = df[df['nutrition-score-fr_100g'].isna() == False].select_dtypes(['int32','float64'])

# %%
df[df['nutrition-score-fr_100g'].isna() == False].select_dtypes(['int32','float64']).isna().sum().sort_values(ascending=False)
# Out:
# additives_n                                0
# ingredients_from_palm_oil_n                0
# ingredients_that_may_be_from_palm_oil_n    0
# energy_100g                                0
# fat_100g                                   0
# saturated-fat_100g                         0
# carbohydrates_100g                         0
# sugars_100g                                0
# fiber_100g                                 0
# proteins_100g                              0
# sodium_100g                                0
# nutrition-score-fr_100g                    0
# dtype: int64

# %%
data_reg = data_reg.drop(['additives_n','energy_100g','ingredients_that_may_be_from_palm_oil_n','ingredients_from_palm_oil_n'], axis=1).dropna(axis=0)

# %%
data_reg
# Out:
#         fat_100g  saturated-fat_100g  carbohydrates_100g  sugars_100g  \
# 0      19.260900                0.80           30.349583        87.70
# 1      19.260900                2.90           30.349583        50.30
# 2       0.000000                0.00           10.400000        10.40
# 3      19.260900               11.00           30.349583         1.00
# 4       0.000000                0.00           10.400000        10.40
# ...          ...                 ...                 ...          ...
# 58205  19.260900               12.00           30.349583        10.50
# 58206   4.322211                1.00           18.218109         1.00
# 58207   2.800000                0.60           74.800000         2.60
# 58208   4.322211                3.73           18.218109         3.89
# 58209   0.200000                0.20            0.500000         0.50
#
#        fiber_100g  proteins_100g  sodium_100g  nutrition-score-fr_100g
# ...

# %%
df['nutrition-score-fr_100g'].dtype
# Out:
# dtype('float64')

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

X = data_reg.copy()
y = X['nutrition-score-fr_100g']
X = X.drop(['nutrition-score-fr_100g'],axis=1)


scaler = StandardScaler()
X = scaler.fit_transform(X)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.15, random_state=42)
lr = LinearRegression().fit(X_train, y_train)
print('R² sur jeu d\'entraînement : ', lr.score(X_train,y_train))
print('R² sur jeu de test', lr.score(X_test,y_test))
print('Poids de chaque variable dans la régression', lr.coef_)
print('ordonnée à l\'origine', lr.intercept_)
# Out:
# R² sur jeu d'entraînement :  0.671117965967897
# R² sur jeu de test 0.6653397804079269
# Poids de chaque variable dans la régression [ 3.33160269  2.75413058  0.83317265  3.56430055 -1.56325863  1.18132213
#   1.15890378]
# ordonnée à l'origine 8.578142566993355

# %%
pd.DataFrame(X_train)
# Out:
#               0         1         2         3         4         5         6
# 0     -0.286508 -0.484478 -0.212948  0.183714 -0.082052 -0.417741 -0.272995
# 1      3.397654 -0.065128 -1.082972 -0.670772 -0.468621 -0.354270  0.159193
# 2     -0.905888 -0.640237  2.316514  3.353751 -0.059362 -0.988980 -0.278202
# 3     -0.610637 -0.496460 -0.394506 -0.586378 -0.210908  0.166192 -0.023055
# 4     -0.904522 -0.637840  2.912937  3.974572 -0.496969 -0.950897 -0.280806
# ...         ...       ...       ...       ...       ...       ...       ...
# 49473  0.289540 -0.220887 -0.875369 -0.370120 -0.059362 -0.519295  0.107123
# 49474 -0.741261 -0.608246 -0.962735 -0.485633 -0.002161 -0.853152 -0.058567
# 49475 -0.899057 -0.640237 -1.134872 -0.639124  0.459145 -0.976285 -0.233812
# 49476 -0.680465 -0.592311 -0.901320 -0.428140  0.098347 -0.823955 -0.045341
# 49477  1.280038  2.115492 -1.139197 -0.691870 -0.623248  1.042091  0.078484
#
# [49478 rows x 7 columns]

# %%
pd.DataFrame(X)
# Out:
#               0         1         2         3         4         5         6
# 0      0.409828 -0.544385  0.130186  3.928683 -0.391307 -0.912815 -0.280806
# 1      0.409828 -0.292775  0.130186  1.955981  0.381831  0.216968 -0.282628
# 2     -0.905888 -0.640237 -0.732643 -0.148586 -0.623248 -0.988980 -0.276796
# 3      0.409828  0.677720  0.130186 -0.644399 -0.262451 -0.036915 -0.075126
# 4     -0.905888 -0.640237 -0.732643 -0.148586 -0.193267 -0.988980 -0.257374
# ...         ...       ...       ...       ...       ...       ...       ...
# 58205  0.409828  0.797535  0.130186 -0.143312 -0.623248  0.115415 -0.207906
# 58206 -0.610637 -0.520422 -0.394506 -0.644399  1.953877  0.280439  2.320136
# 58207 -0.714620 -0.568348  2.052686 -0.560005  0.897256  0.661265 -0.106368
# 58208 -0.610637 -0.193329 -0.394506 -0.491963  2.520845  1.704728 -0.257374
# 58209 -0.892226 -0.616274 -1.160822 -0.670772 -0.571706 -0.925509 -0.276796
#
# [58210 rows x 7 columns]

# %%
resultat = pd.DataFrame({'nutriscore_reel' : y_test, 'prediction' : lr.predict(X_test)}).reset_index()

plt.figure(figsize=(8,8))
plt.axis('equal')
plt.title('Comparaison des nutriscores estimés linéairement et réels')
sns.scatterplot(x = resultat['nutriscore_reel'], y = resultat['prediction'], alpha=0.3, color='steelblue')
sns.lineplot([0 , 30], [0, 30], color='red')
ax = plt.gca()
ax.set_xlim(0,30)
ax.set_ylim(0,30)
plt.show()
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
compare = abs(resultat['nutriscore_reel'] - resultat['prediction'])
compare.sum()/len(compare)
# Out:
# 3.990387925794583

# %%
from sklearn.metrics import mean_squared_error
from math import sqrt

print('root mean squared error : ', sqrt(mean_squared_error(y_true = resultat['nutriscore_reel'], y_pred = resultat['prediction'])))
# Out:
# root mean squared error :  5.218201766997675
